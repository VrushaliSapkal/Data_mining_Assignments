# %% [markdown]
# <a href="https://colab.research.google.com/github/VrushaliSapkal/Data_mining_Assignments/blob/main/DMW06.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
data=pd.read_csv("/content/APPL_DATA.csv")

# %%
data
# Out:
#              Date        High         Low        Open       Close  \
# 0      1980-12-12    0.128906    0.128348    0.128348    0.128348
# 1      1980-12-15    0.122210    0.121652    0.122210    0.121652
# 2      1980-12-16    0.113281    0.112723    0.113281    0.112723
# 3      1980-12-17    0.116071    0.115513    0.115513    0.115513
# 4      1980-12-18    0.119420    0.118862    0.118862    0.118862
# ...           ...         ...         ...         ...         ...
# 10559  2022-10-28  157.500000  147.820007  148.199997  155.740005
# 10560  2022-10-31  154.240005  151.919998  153.160004  153.339996
# 10561  2022-11-01  155.449997  149.130005  155.080002  150.649994
# 10562  2022-11-02  152.169998  145.000000  148.949997  145.029999
# 10563  2022-11-03  142.794998  139.259995  142.059998  139.809296
#
#             Volume   Adj Close
# 0      469033600.0    0.100039
# 1      175884800.0    0.094820
# 2      105728000.0    0.087861
# 3       86441600.0    0.090035
# ...

# %%
data.shape
# Out:
# (10564, 7)

# %%
data.isnull().sum()
# Out:
# Date         0
# High         0
# Low          0
# Open         0
# Close        0
# Volume       0
# Adj Close    0
# dtype: int64

# %%
data.columns
# Out:
# Index(['Date', 'High', 'Low', 'Open', 'Close', 'Volume', 'Adj Close'], dtype='object')

# %% [markdown]
# # Visualization Technique1- Histogram

# %%
data.hist()
plt.show()

# %% [markdown]
# # 2 : Density Plot

# %%
#Density Plots
#A density plot appears to be an abstracted histogram. Each bin has a smooth curve drawn through its top
data.plot(kind='density',subplots=True,sharex=False)
plt.show()

# %% [markdown]
# # 3 : Box Plot

# %%
#A box plot summarizes how each attribute is distributed.
data.plot(kind='box',subplots=True,sharex=False,sharey=False)
# Out:
# High            AxesSubplot(0.125,0.125;0.110714x0.755)
# Low          AxesSubplot(0.257857,0.125;0.110714x0.755)
# Open         AxesSubplot(0.390714,0.125;0.110714x0.755)
# Close        AxesSubplot(0.523571,0.125;0.110714x0.755)
# Volume       AxesSubplot(0.656429,0.125;0.110714x0.755)
# Adj Close    AxesSubplot(0.789286,0.125;0.110714x0.755)
# dtype: object

# %% [markdown]
# # 4 : ScatterMatrix

# %%
pd.plotting.scatter_matrix(data)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f94d6204ca0>,
# ...
#       dtype=object)

# %% [markdown]
# # 5 : Bar Plot

# %%
import seaborn as sns

# %%
sns.barplot(data['Volume'],data['Open'])
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# Scatter plot with day against tip
plt.scatter(data['High'], data['Low'], c=data['Open'],
            s=data['Close'])
 
# Adding Title to the Plot
plt.title("Scatter Plot")
 
# Setting the X and Y labels
plt.xlabel('High')
plt.ylabel('Low')
 
plt.colorbar()
 
plt.show()
